# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

df = pd.read_csv('/Users/cheryl/Desktop/IE7275/hw1/BostonHousing.csv')

# %%
X = df[['TAX']]
y_true = df[['MEDV']]

# split the dataset into tranining and testing sets
df_training = df.loc[ :350]
df_testing = df.loc[351: ]

x_training = df_training[['TAX']]
y_training = df_training[['MEDV']]

x_testing = df_testing[['TAX']]
y_testing = df_testing['MEDV']

# %% [markdown]
# Part 1 Linear Regression

# %%
# implement a linear regression model
model =  LinearRegression()
model.fit(x_training, y_training)
# Out:
# LinearRegression()

# %%
# Make prediction on the testing data
y_pred = model.predict(x_testing)

# %%
# Calculate the coefficients
b0 = model.intercept_
b1 = model.coef_[0]

# Plotting the data points and the regression line
plt.scatter(X, y_true, color='blue', label='Actual Data')
plt.plot(x_testing, y_pred, color='red', label='Linear Regression Line')
plt.xlabel('RM (Average Number of Rooms)')
plt.ylabel('MEDV (Median Value of Homes)')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
# Evaluate the model
# Calculate the MSE and R2
mse = mean_squared_error(y_testing, y_pred)
r2 = r2_score(y_testing, y_pred)
print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2): {r2}")
# Out:
# Mean Squared Error (MSE): 79.46543453657416
# R-squared (R2): -0.19338536145118446

# %% [markdown]
# Part 2 Multiple Linear Regression

# %%
# Set the independent variables
# X2 = df[[ 'CRIM','AGE','TAX','RM']]
X2 = df[[ 'CRIM','TAX','AGE']]
X2_training = X2.loc[ :350]
X2_testing = X2.loc[ 351: ]

# %%
# Create a Multiple Linear Regression model
model = LinearRegression()

# Fit the model to the training data
model.fit(X2_training, y_training)
# Out:
# LinearRegression()

# %%
# Make prediction on the testing set
y_pred2 = model.predict(X2_testing)

# %%
#Evaluate the Model
mse_2 = mean_squared_error(y_testing, y_pred2)
r2_2 = r2_score(y_testing, y_pred2)

print(f"Mean Squared Error (MSE): {mse_2}")
print(f"R-squared (R2): {r2_2}")
# Out:
# Mean Squared Error (MSE): 76.14122294933338
# R-squared (R2): -0.1434634618263393

# %%
fig = px.scatter_3d(df, x = 'RM', y = 'CRIM', z = 'MEDV')
fig.show()
